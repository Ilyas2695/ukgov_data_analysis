# %%
import seaborn as sns
import pandas as pd


df = pd.read_csv('../data/processed/ACY_05M.csv')
sns.lineplot(data=df, x="Month", y="Initial Decisions")
# Out:
# <Axes: xlabel='Month', ylabel='Initial Decisions'>
